# %% [markdown]
# ```
# in this session we will explore and define those terms
# what is Random forest?
# what is desion tree?
# important terms in random forest
# working of random forest
# advantage of Random forest
# Disadvantage of Random forest
# Hands on random forest
# ```

# %% [markdown]
# ```
# Random Forest is constructed using multiple desion tree and the final desion is obtained by using majority vote of the desion tree.taking the majority vote is in the case of classification while in the case of regression we use mean to take a desion
#
# Desion tree is also an important topic which is comprised from three different node called Root Node,desion node and leaf node.
# root node:a node where the entire data set is fed
# desion node:node where desion is taking place and split perform
# leaf node: it is final node where prediction are made

# %% [markdown]
# ```
# let's try to understand how different penguin species classifield using a desion tree those species are called gentoo,adelie and chinstrap
#
# before that understand how the desion tree is constructed
# so the first measure is taken a subset of the data(in our case the penguin data) from the subset of the data we will have a target variable in our case species is our tareget variable island and body mass are considered as subset of our data
#
# one of the basic drawback of desion tree that random forest overcome is: in the case of huge data a desion tree would have gone to a huge depth and this huge depth would have led to overffiting of the data this basic drawback of the desion tree

# %% [markdown]
# ```
# in the next part what we will see is what is importance Terms the random forest?
# so there are 4 important terms in Random forest which are
# Root-node:where the training data set is fed
# splitting-node:we use gini or entrophy methods to do these steps
# desion-NOde:provide a link to the desion node
# lead-node:where no further division take place and prediction made

# %% [markdown]
# ```
# the next important steps is working on the random forest
# the first term in this part is random sample with replacement
# random sampling means just selecting some rows randomly from subsets of the data and creating further subset so when we comes on replacement when we are working on reapeated rows without deletaion
#
# How feature selection is done on the random forest?
# so in the case of classification:by default feature selection is done by taking square root of the total number of all the feature
# in the case of regression:by default feature selection is held by dividing the total number of the feature by 3
#
# What is ensemble technique or bootstrap aggregation?
# so ensembling means aggregating the result of the desion tree and taking majority vote in the case of classfication and taking the mean value in the case of reggresion
#
# What are the splitting method?so what are the splitting methods we use in the random forest?
# the first method is gini impurity method:used to predict the likelihood of randomly selected example would be classifield incorrectly.which ranges from 0 to 1 0 indicate all of the element belong to a single class while 1 indicate only 1 class exists so values like 0.5 indicate the elements are uniformly distributed on the classes
#
# information gain is the secound method of splitting that random forest use:feature is selected that countain most information about a class.utile entropy:
# entropy is nothing but measure  uncertainity or randomness of the data.
# so when our enropy becomes more high means our data looks so messy or full of randomness so when we comes from the root node to the decion node these entropy become less or we have low entropy. so low entropy means we are likely that the prediction more accurate and we can make prediction very easily as compared to the messy data

# %% [markdown]
# ```
# advantage of the random forest?
# 1:having a low variance because we use multiple desion tree
# 2:reduce overfitting:because we are working with multiple desion tree it reduce the depth of the tree so we are get reduced overfitting.we use bootstrap aggregation to find out the result
# 3:Normalization not needed(required):because it works on rule based approach
# 4:Good accuracy:it gives a nice prediction as well as precion compared to other machine learning classifier such as navbar,knn,sbm
# in general it can suitable for both classification and reggresion it can work with countinous and discrete data,perform well on the large dataset
#
# Disadvantage of the Random forests
# 1:it require more training time
# 2:the interpretaion is become really complex because Random forest is the combination of multiple desion tree
# 3:it require more memory utilization
# 4:computationally expensive
# so those are the major disadvantage of the Random Forest classifier
